# %% [markdown]
# # 第三週：基本文字資料的處理 (中文)

# %% [markdown]
# 本週課程為「基本文字資料的處理」，目的為了解基本的文字處理概念。文字處理的步驟會因所要分析之語言不同而有所差異，在這個Jupyter Notebook當中將會展示「中文」的文字處理過程，並且搭配python程式碼進行講解。在後面的內容中，我們將會介紹所使用到的套件、文字處理基本流程、實際應用等三個部分。

# %% [markdown]
# ## 大綱
# 1. 套件說明
# 2. Tidy Data 示範
# 3. 文字處理基本流程示範
#     - 3.1 建立示範中文文本
#     - 3.2 中文斷詞
#     - 3.3 去除停用字
# 4. 實際應用(Ptt文章)
#     - 4.1 中文斷詞
#     - 4.2 去除停用字
#     - 4.3 更新斷詞及停用字詞典
#     - 4.4 結果比較

# %% [markdown]
# ## 1. 套件說明
#
# 下面列出在本次實作過程中我們所使用到的相關套件，在這個Notebook當中我們將會簡單的展示這些套件的使用方式，關於各個套件的進階使用請同學參照其官網的說明。
#
# - Pandas : 一個資料分析的函式庫，提供了DataFrame等資料格式，與資料處理的函數。
# - jieba : 中文斷詞套件
# - re : 正規表達式套件。
# - wordcloud : 文字雲繪圖工具。
# - matplotlib : 繪圖工具。

# %% [markdown]
# #### Google Colab 套件安裝
# 這次會使用到的套件Colab都內建好了，若在Google Colab環境下要安裝套件的話須在指令前加驚嘆號。
# ```
# !pip install 套件名稱
# ```

# %%
# !pip install pandas
# !pip install jieba
# !pip install wordcloud

# %% [markdown]
# 引入套件

# %%
import pandas as pd
import jieba
import jieba.analyse
import re
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %% [markdown]
# #### 繪圖相關設定

# %%
# 設定圖的字體大小
plt.rcParams['font.size'] = 14

# 設定圖的中文字體 (無法顯示的話可以試試‘Microsoft JhengHei’字體)
# 也可參考：https://pyecontech.com/2020/03/27/python_matplotlib_chinese/
# plt.rcParams['font.sans-serif'] = ['Arial Unicode Ms']
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei']

# 設定文字雲中文字體路徑
FontPath = 'raw_data/SourceHanSansTW-Regular.otf' # 設定字型

# %% [markdown]
# ## 2. Tidy Data
# 在進行資料分析的過程當中，資料清理是一個不可或缺的環節，資料清理的精細程度也會直接影響結果好壞。而在機器學習的領域當中，我們通常會將文字型資料(Textual Data)視為是一種非結構化資料(Unstructure Data)。這樣的非結構化資料是需要透過特定的清理方式將其轉為結構化資料之後，才能夠為後續分析使用。這樣的處理方式我們將其稱為Data Tidying。而處理過後的「乾淨」的資料，我們就把它叫做Tidy Data。其定義的原則如下：
#
# 1. 每個變數分別在個別的欄位。
# 2. 每筆觀察值形成一列。
# 3. 不同主題要用不同table來整理。

# %% [markdown]
# 接著我們用一個範例來介紹Tidy Data。
#
# 下面圖片中的兩個表格是使用相同的資料，但不同的表達方式。其概念都是要用來描述不同的人(person)在不同的實驗(treatmenta, treatmentb)當中的結果(表格中的數字)。
#
# <img src="./pic/untidy.png" alt="untidy_table" width="400"/>

# %% [markdown]
# 而這樣的資料其實是不利於資料分析的進行的。我們用剛才所定義的原則來將資料轉換為Tidy Data(如下圖中的表格)，可以看到資料其實是包含了三個變數、六個觀察值。也就是說我們可以用一個Pandas的DataFrame來表達資料。
#
# <img src="./pic/tidy_table.png" alt="tidy_table" width="400"/>

# %% [markdown]
# #### Tidy Data 小練習
# 我們將建立出一個Pandas DataFrame的物件來儲存資料，這裡用Python Dict來建立DataFrame。Dict裡的key值(下面的treatment、John Smith...)對應到一個欄位的名稱，而其值(value)則是其欄位裡的所有值。

# %%
treatmentData = pd.DataFrame({
    'treatment':['a', 'b'],
    'John Smith':[None, 2],
    'Jane Doe':[16, 11],
    'Mary Johnson':[3, 1]
})
treatmentData
# Out:
#   treatment  John Smith  Jane Doe  Mary Johnson
# 0         a         NaN        16             3
# 1         b         2.0        11             1

# %% [markdown]
# 將以上非Tidy 格式的dataframe使用pandas的function將其轉換成Tidy格式

# %%
treatmentData_melt = pd.melt(treatmentData, id_vars=['treatment'])
treatmentData_melt
# Out:
#   treatment      variable  value
# 0         a    John Smith    NaN
# 1         b    John Smith    2.0
# 2         a      Jane Doe   16.0
# 3         b      Jane Doe   11.0
# 4         a  Mary Johnson    3.0
# 5         b  Mary Johnson    1.0

# %% [markdown]
# 接著去除資料中的空值

# %%
treatmentData_melt = treatmentData_melt.dropna(subset=['value'])
treatmentData_melt
# Out:
#   treatment      variable  value
# 1         b    John Smith    2.0
# 2         a      Jane Doe   16.0
# 3         b      Jane Doe   11.0
# 4         a  Mary Johnson    3.0
# 5         b  Mary Johnson    1.0

# %% [markdown]
# 查看兩種 treatment 的出現次數

# %%
treatmentData_melt.groupby(by = ['treatment'], as_index = False).size()
# Out:
#   treatment  size
# 0         a     2
# 1         b     3

# %% [markdown]
# 分析或處理資料時經常會使用```groupby```函式來對資料進行分群。
#
# 更多相關的使用方法可參考[官網](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html)
#
# <img src="./pic/pandas-groupby.svg" alt="pandas groupby illustration" width="500"/>

# %% [markdown]
# ```Method Chaining```
#
# Method chaining是一種程式碼的撰寫風格，將某一段程式碼產生的結果直接導向另一段程式碼，使程式碼更加簡潔、好讀。
# 使用pandas套件時也可以利用此方法，讓上述的好幾行程式碼整合成以下的樣子：

# %%
treatment_count = treatmentData.melt(id_vars=['treatment']).dropna(subset=['value']).groupby(by = ['treatment'], as_index = False).size()
treatment_count
# Out:
#   treatment  size
# 0         a     2
# 1         b     3

# %% [markdown]
# ## 3. 文字處理基本流程
# 接下來的章節我們將介紹文字處理的基本流程。其中大概可以分為六個步驟
#
# + **資料蒐集：** <br>
# 如同上面所述，文字型資料被視為是一種非結構化的資料。
# 其資料來源相當的廣泛，如：論壇、新聞網、社群媒體、專利、論文等...。
# 其中，論壇、新聞網、社群媒體這類由使用者所產生出來的資料我們將其稱為User Generated Data(UGC)。
# 通常來說，我們會使用網路爬蟲的技術來取得這樣的資料(網路爬蟲的技術不會在此範例中討論)。 <br><br>
# + **資料初步清理：** <br>
# 將文字內容轉為正規的語句，例如：去除特定標籤、符號、統一標點符號的使用等等。<br><br>
# + **斷句斷詞：** <br>
# 使用工具區隔文章中不同的句子、詞彙 <br><br>
# + **去除停用字：** <br>
# 停用字就是與分析無關的詞彙，甚至這些詞彙可能會影響分析的結果。
# 因此我們必須在資料處理的過程中將其排除。例如：語助詞 <br><br>
# + **產生結構化資料：** <br>
# 根據需求產生不同結構化資料(Tidy Data)，以供後續分析使用。 <br><br>
# + **應用更多分析：** <br>
# 進行不同的分析，例如：詞頻分析、情緒分析、文辭和文件分析、文件分類、社會網路分析等等。

# %% [markdown]
# ### 3.1 建立示範文本

# %%
chinese_text = """近幾年來「良心投資」逐漸形成一股風潮，投資人對於企業社會責任愈來愈重視，環境保護、社會責任與公司治理加總的ESG概念，
                也成為當今華爾街和法人投資圈最熱門的熱搜關鍵英文縮寫。什麼是「ESG」？就是環境保護（Environmental）、社會責任（Social）與公司治理（Governance）
                這3個英文字的縮寫，從政府推動限塑政策、上市公司需編製與申報企業社會責任報告書、民間團體自動發起淨灘活動等，背後都蘊含著ESG的意涵。
                ESG投資可以回溯到2006年聯合國責任投資原則（UNPRI）的成立，致力於推動全球各大投資機構在投資決策過程中必須納入ESG因子，
                並協助PRI的簽署國家全面提升責任投資的能力。戮力經營本業的企業，若不重視ESG，就算有好的本益比、好的成長，也會影響公司價值，
                尤其是近年來環境變遷等「無差別衝擊」影響企業經營表現，投資人轉向從ESG、SDGs（聯合國永續發展目標）等評價模式尋找投資標的。"""

example_df = pd.DataFrame({'text': [chinese_text]})
example_df
# Out:
#                                                 text
# 0  近幾年來「良心投資」逐漸形成一股風潮，投資人對於企業社會責任愈來愈重視，環境保護、社會責任與...

# %% [markdown]
# ### 3.2 中文斷詞

# %% [markdown]
# 斷詞引擎設定：使用 Jieba 當作斷詞系統。
#
# Jieba原先內建為簡體字字典，但我們可以使用繁體字典來做為替換，結果會比較好。另外可能還有一些專有名詞是沒有被包含在預設字典當中，我們也可以使用自定義字典的方式加入，或者使用參數的形式帶入。

# %%
# 初始化斷詞引擎：不一定要設定，只使用內建效果也可以
# 參考網址：https://raw.githubusercontent.com/ldkrsi/jieba-zh_TW/master/jieba/dict.txt
jieba.set_dictionary('./dict/dict.txt') 

# 載入自定義辭典：一個詞一行，每行分詞語、詞頻(可省)、詞性(可省)
jieba.load_userdict('./dict/user_dict.txt')

# 參數形式手動將字詞加入斷詞字典
words = ['良心投資','投資圈','熱搜','公司治理']
for w in words:
    jieba.add_word(w, freq=None, tag=None)
# Out:
# Building prefix dict from c:\Users\USER\Desktop\final_scribble\SMA\week3\dict\dict.txt ...
# Loading model from cache C:\Users\USER\AppData\Local\Temp\jieba.ubfee459443432e547097c5e5c585a055.cache
# Loading model cost 0.418 seconds.
# Prefix dict has been built successfully.

# %% [markdown]
# 使用jieba套件的斷詞函式來實作斷詞，並利用pandas套件將文件整理成我們要的格式。步驟解釋如下：
#
# + ```assign``` : 新增一個欄位「word」，值為 example_df['text'] 進行jieba.lcut的結果
#
# + ```apply``` : 將jieba.lcut函式應用於 example_df['text'] 的每一行。
#
# + ```explode``` : jieba.lcut的結果為list，因此用explode將list裡的每個值變單獨一行
#
# + ```drop``` : 將欄位「text」刪除，axis=1為對縱軸操作(column)，axis=0為對橫軸操作(row)
#
#
# ***大家可以試著將explode()或drop()拿掉，看看結果有什麼變化***

# %%
example_df = example_df.assign(word = example_df['text'].apply(jieba.lcut))
example_df.head(10)

# %% [markdown]
# ### 3.3 移除停用字（無意義的字、標點符號）

# %%
# 匯入檔案形式
stopwords = []

# 對於這段文字所定義的停用字列表
with open(f'./dict/text_stopwords.txt','r',encoding="utf8") as f:
    stopwords = f.read().splitlines() #移除換行符號\n

# 參數形式手動加入停用字
user_stop = ["的", "來", "對於", "愈來愈", "就是", "什麼"]
for i in user_stop:
    stopwords.append(i)

print(stopwords)
# Out:
# ['，', '「', '」', '、', '。', '？', '（', '）', '"', '的', '來', '對於', '愈來愈', '就是', '什麼']

# %% [markdown]
# 篩選掉word欄位裡的停用字

# %%
example_df = example_df[~example_df['word'].isin(stopwords)]
example_df.head(10)
# Out:
#    word
# 0    幾年
# 0  良心投資
# 0    逐漸
# 0    形成
# 0    一股
# 0    風潮
# 0   投資人
# 0    企業
# 0    社會
# 0    責任

# %% [markdown]
# 除了停用字字典以外，也可另外使用其他篩選條件，如：字詞長度小於2則不納入考慮

# %%
example_df = example_df[example_df['word'].str.len() > 1]
example_df.head(10)
# Out:
#    word
# 0    幾年
# 0  良心投資
# 0    逐漸
# 0    形成
# 0    一股
# 0    風潮
# 0   投資人
# 0    企業
# 0    社會
# 0    責任

# %% [markdown]
# 在Python中的資料表可使用Pandas DataFrame儲存，Pandas套件也提供了許多的函數可以進行資料的轉換與操作
#
# 有關DataFrame的操作可參考Pandas官網的[教材](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html)

# %% [markdown]
# ## 4. 實際應用：以PPT美食版的文本為例

# %% [markdown]
# 網路爬蟲的技術不會在此範例中討論，在後續的範例中，我們將以爬取下來的PTT文章來說明文字分析的技術。

# %% [markdown]
# ### 4.1 資料介紹
# 資料來源：
# + 東森新聞裡有關以巴衝突的新聞
# + 關鍵字：「以巴衝突, 以色列, 巴勒斯坦」
# + 時間： 2023-10-07 ~ 2024-03-09
# + 資料筆數：共 605 篇新聞

# %% [markdown]
# 讀取ptt檔案zh_buffet_20_22.csv

# %%
df = pd.read_csv('raw_data/Israel–Hamas_war.csv')
df
# Out:
#      system_id                             artTitle  \
# 0            1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞
# 1            2    槍手滲透城鎮！以色列遭哈瑪斯火箭猛襲 至少22死、數百傷｜東森新聞
# 2            3         哈瑪斯突襲以色列至少22死數百傷 外交部回應了｜東森新聞
# 3            4   以色列爆戰爭！哈瑪斯5千火箭狂轟 17人台灣旅行團受困當地｜東森新聞
# 4            5            以巴衝突增至232死 以國22地點爆激戰｜東森新聞
# ..         ...                                  ...
# 600        601        加薩戰爭迄今近5個月 以色列地方選舉成民意風向球｜東森新聞
# 601        602          密州初選拜登川普雙過關 選民動向備受兩黨關注｜東森新聞
# 602        603            拜登稱停火在即遭以哈打臉 卡達態度洩玄機｜東森新聞
# 603        604            加薩搶糧混戰逾百死 拜登：美軍將空投物資｜東森新聞
# 604        605            以巴衝突滿五個月！ 美軍持續空投加薩物資｜東森新聞
#
#                                           artUrl          artDate artCatagory  \
# 0    https://news.ebc.net.tw/news/article/385783  10/7/2023 18:49          國際
# 1    https://news.ebc.net.tw/news/article/385785  10/7/2023 19:20          國際
# 2    https://news.ebc.net.tw/news/article/385796  10/7/2023 20:05          國際
# 3    https://news.ebc.net.tw/news/article/385802  10/7/2023 20:36          國際
# 4    https://news.ebc.net.tw/news/article/385820   10/8/2023 8:35          國際
# ..                                           ...              ...         ...
# 600  https://news.ebc.net.tw/news/article/407418   2/28/2024 6:30          國際
# 601  https://news.ebc.net.tw/news/article/407510  2/28/2024 16:08          國際
# 602  https://news.ebc.net.tw/news/article/407559  2/28/2024 19:11          國際
# 603  https://news.ebc.net.tw/news/article/407989   3/2/2024 15:09          國際
# 604  https://news.ebc.net.tw/news/article/408692   3/6/2024 17:16          國際
#
#                                             artContent dataSource
# 0    法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...        EBC
# 1    伊斯蘭主義運動組織「哈瑪斯」今天對以色列發動近年規模最大突襲，除有槍手滲透到以色列城鎮，還在...        EBC
# 2    伊斯蘭主義運動組織「哈瑪斯」（Hamas）對以色列發動突襲，外交部今天表示，經駐以色列代表處...        EBC
# 3    伊斯蘭主義運動組織「哈瑪斯」今（7）日對以色列展開攻擊，發射5000枚火箭，而以色列總理也證...        EBC
# 4    巴勒斯坦伊斯蘭主義團體「哈瑪斯」對以色列發動大規模攻擊，以方隨後展開反擊。根據加薩走廊（Ga...        EBC
# ..                                                 ...        ...
# 600  以色列昨天舉行兩度延宕的市議員選舉，隨著以哈戰爭爆發近5個月，這場選舉讓外界得以從中一窺以色...        EBC
# 601  美國密西根州今天舉行兩黨總統提名初選，民主黨籍的現任總統拜登和共和黨參選人川普雙雙取勝，然而...        EBC
# 602  美國總統拜登26號才說以色列跟哈瑪斯有望在3月4號停火，慘遭雙方打臉否認。另一方面，負責斡旋...        EBC
# 603  加薩市昨天發生以色列軍人被控朝搶糧的巴勒斯坦人開槍造成逾百死事件，當地人道災難持續惡化再度引...        EBC
# 604  堆高機把物資放到運輸機上，箱子旁印著約旦國旗，還有手寫字條，寫著與你同在為你祈禱。約旦空軍5...        EBC
#
# [605 rows x 7 columns]

# %% [markdown]
# ### 4.2 資料初步清理
# - 清除內文為空值的文章
#
# - 透過觀察發現ptt的文章常用兩個換行符號作為句子的結尾，因此將兩個換行取代為句號。
#
# - 清除不重要的字如換行、網址

# %%
clear_df = df.copy()

#去除本次不會用到的欄位
drop_cols = ['system_id', 'artUrl','artCatagory', 'dataSource']
clear_df.drop(drop_cols, axis = 1, inplace = True)

#去除文章內容為空值的筆數
clear_df.dropna(subset = ['artContent'], axis=0, how='any', inplace=True)

#新增['sentence']欄位，用'。'取代'\n\n'，並移除'\n'
clear_df['sentence'] = clear_df['artContent'].str.replace(r'\n\n','。', regex=True)
clear_df['sentence'] = clear_df['sentence'].str.replace(r'\n','，', regex=True)

#移除內文中的網址
clear_df['sentence'] = clear_df['sentence'].replace(r'http\S+', '', regex=True).replace(r'www\S+', '', regex=True)

clear_df.head(10)
# Out:
#                               artTitle          artDate  \
# 0  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1    槍手滲透城鎮！以色列遭哈瑪斯火箭猛襲 至少22死、數百傷｜東森新聞  10/7/2023 19:20
# 2         哈瑪斯突襲以色列至少22死數百傷 外交部回應了｜東森新聞  10/7/2023 20:05
# 3   以色列爆戰爭！哈瑪斯5千火箭狂轟 17人台灣旅行團受困當地｜東森新聞  10/7/2023 20:36
# 4            以巴衝突增至232死 以國22地點爆激戰｜東森新聞   10/8/2023 8:35
# 5     「台灣5團124人」在以色列！外交部：旅客、台僑都平安｜東森新聞  10/8/2023 10:19
# 6    哈馬斯5千火箭彈發動襲擊「以色列備戰」 你要知道的幾件事｜東森新聞  10/8/2023 11:08
# 7           哈瑪斯突襲以色列釀數百死 多國發聲挺以色列｜東森新聞  10/8/2023 14:20
# 8        哈瑪斯5000枚火箭襲 以色列以軍飛彈反擊畫面曝｜東森新聞  10/8/2023 14:20
# 9       最糟糕的情況！黎巴嫩發動炮擊 以色列國防軍正式反擊｜東森新聞  10/8/2023 15:10
#
#                                           artContent  \
# 0  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...
# 1  伊斯蘭主義運動組織「哈瑪斯」今天對以色列發動近年規模最大突襲，除有槍手滲透到以色列城鎮，還在...
# 2  伊斯蘭主義運動組織「哈瑪斯」（Hamas）對以色列發動突襲，外交部今天表示，經駐以色列代表處...
# 3  伊斯蘭主義運動組織「哈瑪斯」今（7）日對以色列展開攻擊，發射5000枚火箭，而以色列總理也證...
# 4  巴勒斯坦伊斯蘭主義團體「哈瑪斯」對以色列發動大規模攻擊，以方隨後展開反擊。根據加薩走廊（Ga...
# 5  以巴局勢急轉直下！巴勒斯坦激進組織「哈瑪斯」，對以色列發動史無前例的多戰線突襲。台灣目前有5...
# 6  巴勒斯坦激進武裝組織哈馬斯（Hamas）於7日對以色列首都特拉維夫在內的多個城市發動突襲，過...
# 7  巴勒斯坦激進武裝組織「哈瑪斯」突襲以色列，造成數百人死亡，消息傳出後，多國發聲力挺以色列，包...
# 8  好幾聲爆炸聲響起，民宅大樓應聲而倒，爆出火光，但是飛彈攻擊沒有停歇。巴勒斯坦激進組織哈瑪斯7...
# 9  巴勒斯坦激進武裝組織哈馬斯（Hamas），於7日從海陸空三路對以色列首都「特拉維夫」在內的多...
#
#                                             sentence
# 0  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...
# 1  伊斯蘭主義運動組織「哈瑪斯」今天對以色列發動近年規模最大突襲，除有槍手滲透到以色列城鎮，還在...
# 2  伊斯蘭主義運動組織「哈瑪斯」（Hamas）對以色列發動突襲，外交部今天表示，經駐以色列代表處...
# 3  伊斯蘭主義運動組織「哈瑪斯」今（7）日對以色列展開攻擊，發射5000枚火箭，而以色列總理也證...
# 4  巴勒斯坦伊斯蘭主義團體「哈瑪斯」對以色列發動大規模攻擊，以方隨後展開反擊。根據加薩走廊（Ga...
# 5  以巴局勢急轉直下！巴勒斯坦激進組織「哈瑪斯」，對以色列發動史無前例的多戰線突襲。台灣目前有5...
# 6  巴勒斯坦激進武裝組織哈馬斯（Hamas）於7日對以色列首都特拉維夫在內的多個城市發動突襲，過...
# 7  巴勒斯坦激進武裝組織「哈瑪斯」突襲以色列，造成數百人死亡，消息傳出後，多國發聲力挺以色列，包...
# 8  好幾聲爆炸聲響起，民宅大樓應聲而倒，爆出火光，但是飛彈攻擊沒有停歇。巴勒斯坦激進組織哈瑪斯7...
# 9  巴勒斯坦激進武裝組織哈馬斯（Hamas），於7日從海陸空三路對以色列首都「特拉維夫」在內的多...

# %% [markdown]
# ### 4.3 斷句
# 中文主要以標點符號進行斷句，並清除空的字串

# %%
clear_df['sentence'] = clear_df['sentence'].str.split("[,，。！!？?]{1,}")

sent_df = clear_df.explode('sentence').reset_index(drop=True)

sent_df.head(10)
# Out:
#                               artTitle          artDate  \
# 0  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 2  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 3  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 4  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 5  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 6  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 7  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 8  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 9  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
#
#                                           artContent  \
# 0  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...
# 2  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...
# 3  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...
# 4  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...
# 5  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...
# 6  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...
# 7  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...
# 8  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...
# 9  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...
#
#                                      sentence
# 0                                     法新社記者報導
# 1                       以色列軍隊今天已對加薩走廊發動至少2次空襲
# 2                                        在此之前
# 3                        哈瑪斯集團從加薩走廊向以色列發射大量火箭
# 4                                 以色列總理尼坦雅胡表示
# 5                                    以色列正處於戰爭
# 6                   英國廣播公司新聞網（BBCNews）引述路透社報導
# 7  以色列總理尼坦雅胡（BenjaminNetanyahu）在社群平台X發表影片聲明表示
# 8                                    以色列正處於戰爭
# 9                                   並表示「我們會贏」

# %% [markdown]
# ### 4.4 斷詞
# 斷詞引擎設定：使用 Jieba 當作斷詞系統。
# Jieba原先內建為簡體字字典，但我們可以使用繁體字典來做為替換，結果會比較好。
# 另外可能還有一些專有名詞是沒有被包含在預設字典當中，我們也可以使用自定義字典的方式加入，或者使用參數的形式帶入。

# %%
# 初始化斷詞引擎：不一定要設定，只使用內建效果也可以
# 參考網址：https://raw.githubusercontent.com/ldkrsi/jieba-zh_TW/master/jieba/dict.txt
jieba.set_dictionary('dict/dict.txt')

# %% [markdown]
# 斷詞前先將標點符號清除，並清除空字串

# %% [markdown]
# ***正規表達式 (Regular Expression)*** 是透過簡單的特定字符規則，從文本中找尋符合對應規則的字串，幾乎常見的程式語言，都有支援正規表達式的操作。
#
# 以下提供幾個範例：
#
# + ```\d```：匹配任何一個數字字符，等同於 [0-9]
#
# + ```\w```：匹配任何一個單詞字符，包括字母、數字和下劃線，等同於 [a-zA-Z0-9_]
#
# + ```\s```：匹配任何一個空白字符，包括空格、換行等
#
# + ```[ ]```：用於定義一個字符集合，匹配集合中的任何一個字符。 例如: [abc] = 匹配字符 a、b 或 c。
#
# + ```[^ ]```：用於定義一個否定字符集合，匹配不在集合中的任何一個字符。 例如: [^abc] = 匹配除了 a、b 和 c 以外的任何字符。
#
# + ```+```：匹配前面提及的元素一次或多次。
#
# 更多有關正規表達式的用法可參考python官網的[介紹](https://docs.python.org/zh-tw/3/library/re.html)

# %%
#去除句子中除了字母、數字、空白字符以外的符號
sent_df['sentence'] = sent_df['sentence'].str.replace(r'[^\w\s]+', '', regex=True).astype(str)

# 把長度小於1的sentence刪掉
sent_df = sent_df[sent_df["sentence"].str.len() > 1]

sent_df.head(10)
# Out:
#                               artTitle          artDate  \
# 0  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 2  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 3  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 4  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 5  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 6  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 7  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 8  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 9  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
#
#                                           artContent  \
# 0  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...
# 2  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...
# 3  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...
# 4  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...
# 5  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...
# 6  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...
# 7  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...
# 8  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...
# 9  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...
#
#                                    sentence
# 0                                   法新社記者報導
# 1                     以色列軍隊今天已對加薩走廊發動至少2次空襲
# 2                                      在此之前
# 3                      哈瑪斯集團從加薩走廊向以色列發射大量火箭
# 4                               以色列總理尼坦雅胡表示
# 5                                  以色列正處於戰爭
# 6                   英國廣播公司新聞網BBCNews引述路透社報導
# 7  以色列總理尼坦雅胡BenjaminNetanyahu在社群平台X發表影片聲明表示
# 8                                  以色列正處於戰爭
# 9                                   並表示我們會贏

# %% [markdown]
# 使用jieba進行斷詞

# %%
word_df = sent_df.assign(word = sent_df['sentence'].apply(jieba.lcut)).explode('word').drop(['sentence'], axis=1)

#去除少於兩個字的詞語
word_df = word_df.loc[word_df['word'].str.len() > 1]

word_df.head(10)
# Out:
# Building prefix dict from c:\Users\USER\Desktop\final_scribble\SMA\week3\dict\dict.txt ...
# Loading model from cache C:\Users\USER\AppData\Local\Temp\jieba.ubfee459443432e547097c5e5c585a055.cache
# Loading model cost 0.409 seconds.
# Prefix dict has been built successfully.
#                               artTitle          artDate  \
# 0  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 0  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 0  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
#
#                                           artContent  word
# 0  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...   法新社
# 0  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    記者
# 0  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    報導
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...   以色列
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    軍隊
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    今天
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...  加薩走廊
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    發動
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    至少
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    空襲

# %% [markdown]
# #### 為了進行前後比較，先透過繪製詞頻圖及文字雲觀察一下目前的資料。

# %% [markdown]
# ### 4.5 計算去除停用字及更新字典前的詞頻

# %%
freq_df = pd.DataFrame(pd.value_counts(word_df['word'])).sort_values(by = ['count'], ascending = False).reset_index()
freq_df.head(10)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7716\36027799.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   freq_df = pd.DataFrame(pd.value_counts(word_df['word'])).sort_values(by = ['count'], ascending = False).reset_index()
#    word  count
# 0   以色列   3702
# 1    瑪斯   2038
# 2    加薩   1429
# 3    我們    875
# 4    美國    851
# 5  巴勒斯坦    688
# 6    他們    666
# 7    攻擊    642
# 8    表示    632
# 9    人質    492

# %% [markdown]
# ### 4.6 視覺化結果

# %% [markdown]
# matplotlib 畫圖中文顯示不出來的問題
#
# * Mac : <a href="https://blog.csdn.net/RivenDong/article/details/118990773">參考方式</a>
# * Windows : <a href="https://medium.com/marketingdatascience/%E8%A7%A3%E6%B1%BApython-3-matplotlib%E8%88%87seaborn%E8%A6%96%E8%A6%BA%E5%8C%96%E5%A5%97%E4%BB%B6%E4%B8%AD%E6%96%87%E9%A1%AF%E7%A4%BA%E5%95%8F%E9%A1%8C-f7b3773a889b">參考方式</a>
# * 暫存查找 path 方式：matplotlib.get_cachedir()

# %% [markdown]
# #### 繪製詞頻為前10高的長條圖

# %%
freq_df.head(10).plot.barh(x = 'word', y = 'count').invert_yaxis()
plt.show()

# %% [markdown]
# #### 繪製文字雲

# %%
# wordcloud的輸入須為dict，因此先將freq_df轉換成成dict
freq_dict = freq_df.set_index('word').to_dict()
freq_dict = freq_dict['count']

freq_dict
# Out:
# {'以色列': 3702,
#  '瑪斯': 2038,
#  '加薩': 1429,
#  '我們': 875,
#  '美國': 851,
#  '巴勒斯坦': 688,
#  '他們': 666,
#  '攻擊': 642,
#  '表示': 632,
#  '人質': 492,
#  '衝突': 485,
#  '已經': 395,
#  '戰爭': 383,
#  '沒有': 381,
#  '加薩走廊': 377,
#  '民眾': 377,
#  '醫院': 375,
#  '組織': 358,
#  '武裝': 355,
#  '地區': 350,
#  '報導': 350,
#  '以巴': 320,
#  '空襲': 318,
#  '總統': 312,
#  '記者': 311,
#  '因為': 305,
#  '拜登': 304,
#  '行動': 303,
#  '平民': 290,
#  '發動': 278,
#  '當地': 273,
#  '造成': 271,
#  '國家': 271,
#  '支持': 266,
#  '就是': 262,
#  '分子': 260,
#  '現在': 256,
#  '軍事': 256,
#  '不過': 255,
#  '伊朗': 249,
#  '目前': 249,
#  '持續': 248,
#  '突襲': 243,
#  '還有': 240,
#  '進行': 235,
#  '死亡': 228,
#  '可能': 224,
#  '10': 222,
#  '指出': 221,
#  '遭到': 217,
#  '一個': 215,
#  '襲擊': 212,
#  '轟炸': 206,
#  '南部': 204,
#  '政府': 204,
#  '安全': 204,
#  '可以': 203,
#  '影片': 202,
#  '進入': 200,
#  '中東': 194,
#  '居民': 189,
#  '看到': 189,
#  '黎巴嫩': 188,
#  '這些': 188,
#  '總理': 187,
#  '正在': 186,
#  '巴勒斯坦人': 186,
#  '恐怖': 185,
#  '甚至': 183,
#  '今天': 183,
#  '人道': 181,
#  'CNN': 180,
#  '官員': 178,
#  '至少': 178,
#  '這是': 178,
#  '發生': 178,
#  '包括': 177,
#  '發言人': 176,
#  '國防軍': 174,
#  '雙方': 174,
#  '根據': 172,
#  '一名': 172,
#  '埃及': 170,
#  '軍方': 166,
#  '部隊': 158,
#  '邊境': 156,
#  '聯合國': 156,
#  '不斷': 156,
#  '國際': 155,
#  '停火': 155,
#  '發射': 154,
#  '自己': 154,
#  '超過': 153,
#  '火箭': 152,
#  '同時': 152,
#  '畫面': 151,
#  '這場': 150,
#  '真主黨': 150,
#  '希望': 148,
#  '伊斯蘭': 147,
#  '北部': 146,
#  '這個': 146,
#  '納坦雅胡': 145,
#  '釋放': 143,
#  '許多': 141,
#  '中國': 139,
#  '目標': 138,
#  '開始': 138,
#  '激進': 138,
#  '飛彈': 134,
#  '其中': 133,
#  '台灣': 133,
#  '軍隊': 133,
#  '認為': 132,
#  '時間': 132,
#  '士兵': 130,
#  '所有': 128,
#  '宣布': 128,
#  '主義': 125,
#  '無法': 124,
#  '以色列人': 123,
#  '展開': 123,
#  '以國': 120,
#  '馬斯': 119,
#  '協議': 119,
#  '提供': 119,
#  '知道': 118,
#  '地面': 118,
#  '以及': 117,
#  '爆發': 117,
#  '警告': 117,
#  '世界': 116,
#  '撤離': 116,
#  '這裡': 116,
#  '受傷': 114,
#  'Hamas': 113,
#  '除了': 112,
#  '人民': 112,
#  '布林肯': 111,
#  '消息': 111,
#  '成為': 111,
#  '媒體': 110,
#  '戰鬥': 110,
#  '呼籲': 110,
#  '戰火': 109,
#  '約旦': 109,
#  '離開': 109,
#  '援助': 109,
#  '聲明': 109,
#  '投票': 107,
#  '小時': 106,
#  '武器': 106,
#  '如果': 106,
#  '不是': 105,
#  '以來': 105,
#  '物資': 105,
#  '為了': 104,
#  '家人': 104,
#  '這次': 104,
#  '人數': 103,
#  '嚴重': 103,
#  '不會': 102,
#  '因此': 102,
#  '第一': 100,
#  '雖然': 100,
#  '導致': 100,
#  '訪問': 99,
#  '人員': 99,
#  '另外': 98,
#  '要求': 97,
#  '恐怕': 97,
#  '綁架': 97,
#  '全球': 97,
#  '更多': 96,
#  '這樣': 96,
#  '出現': 96,
#  '品牌': 95,
#  '任何': 95,
#  '情況': 94,
#  '準備': 94,
#  '現場': 94,
#  '卡達': 94,
#  '喪命': 94,
#  '英國': 94,
#  '關係': 94,
#  'iPhone15': 93,
#  '強調': 93,
#  '必須': 92,
#  '殺害': 91,
#  '團體': 90,
#  '最後': 90,
#  '領袖': 89,
#  '非常': 89,
#  '大規模': 88,
#  '問題': 87,
#  '告訴': 87,
#  '如今': 87,
#  '受到': 86,
#  '作戰': 86,
#  '軍人': 86,
#  '火箭彈': 86,
#  '無人機': 85,
#  '過去': 84,
#  '境內': 82,
#  '救援': 82,
#  '情報': 81,
#  '還是': 81,
#  '局勢': 81,
#  '只是': 80,
#  '地方': 80,
#  '傷亡': 79,
#  '附近': 79,
#  '事件': 78,
#  '和平': 78,
#  '傳出': 78,
#  '爆炸': 77,
#  '發現': 77,
#  '份子': 77,
#  '一場': 77,
#  '地面戰': 76,
#  '需要': 76,
#  '大量': 76,
#  '外交部': 76,
#  '繼續': 76,
#  '接受': 75,
#  '當時': 75,
#  '保護': 75,
#  '俄羅斯': 74,
#  '使用': 74,
#  '白宮': 74,
#  '威脅': 74,
#  '證實': 74,
#  '烏克蘭': 74,
#  '運動': 74,
#  '顯示': 74,
#  '由於': 74,
#  '遺體': 73,
#  '擴大': 73,
#  '對於': 73,
#  '路透社': 72,
#  '似乎': 72,
#  '地道': 72,
#  '重要': 71,
#  '怎麼': 71,
#  '無辜': 71,
#  '聽到': 71,
#  '試圖': 71,
#  '結束': 71,
#  '針對': 71,
#  '前往': 71,
#  '系統': 70,
#  '大選': 70,
#  '新聞': 70,
#  '不只': 70,
#  '直接': 70,
#  '全面': 69,
#  '危機': 69,
#  '外界': 69,
#  '什麼': 69,
#  '公民': 69,
#  '阿拉伯': 69,
#  '獲釋': 68,
#  '孩子': 68,
#  '而且': 68,
#  '代表': 68,
#  '失去': 67,
#  '之後': 67,
#  '戰事': 67,
#  '喪生': 67,
#  '網路': 67,
#  '狀況': 66,
#  '坦克': 66,
#  '完全': 66,
#  '透露': 66,
#  '譴責': 66,
#  '愛的': 66,
#  '擔心': 65,
#  '父親': 65,
#  '緊張': 65,
#  '只有': 65,
#  '不要': 65,
#  '行為': 65,
#  '協助': 64,
#  '美軍': 64,
#  '地點': 64,
#  '加碼': 64,
#  '回應': 64,
#  '成員': 64,
#  '法新社': 64,
#  '音樂節': 64,
#  '2024': 64,
#  '24': 63,
#  '避免': 63,
#  '警報': 63,
#  '領導人': 63,
#  '達成': 62,
#  '緊急': 62,
#  '是否': 62,
#  '屠殺': 62,
#  '特拉維夫': 62,
#  '國務卿': 62,
#  '普丁': 61,
#  '建築': 61,
#  '很多': 61,
#  '社區': 61,
#  '12': 61,
#  '相當': 61,
#  '反擊': 60,
#  '能夠': 60,
#  '引發': 60,
#  '公布': 60,
#  '將會': 60,
#  '外交': 60,
#  '這一': 60,
#  '一切': 59,
#  '國防部長': 59,
#  '之間': 59,
#  '工作': 59,
#  '聖戰': 59,
#  '區域': 58,
#  '至今': 58,
#  '當局': 58,
#  '一次': 58,
#  '女兒': 58,
#  '關注': 58,
#  '嬰兒': 58,
#  '透過': 58,
#  '摧毀': 58,
#  '入侵': 58,
#  '活動': 58,
#  '11': 58,
#  '難民': 57,
#  '再度': 57,
#  '小孩': 57,
#  '兒子': 57,
#  '發布': 57,
#  '控制': 57,
#  '如何': 56,
#  '抵達': 56,
#  '成功': 56,
#  '30': 56,
#  '幾乎': 56,
#  '拉法': 56,
#  '大陸': 56,
#  '擊中': 55,
#  '人士': 55,
#  '家屬': 55,
#  '衛生部': 55,
#  '消滅': 55,
#  '開戰': 55,
#  'GazaStrip': 55,
#  '隧道': 54,
#  '當中': 54,
#  '醫療': 54,
#  '基地': 54,
#  '打擊': 54,
#  '整個': 54,
#  '報復': 54,
#  '城市': 53,
#  '不少': 53,
#  '照片': 53,
#  '主席': 53,
#  '戰場': 53,
#  '攻勢': 52,
#  '西方': 52,
#  '昨天': 52,
#  '死傷': 52,
#  '尼坦雅': 52,
#  '政治': 52,
#  '男子': 52,
#  '原本': 52,
#  '主要': 52,
#  '公開': 51,
#  '封鎖': 51,
#  '想要': 51,
#  '休戰': 51,
#  '採取': 51,
#  '影響': 51,
#  '各國': 51,
#  '燃料': 50,
#  '耶路撒冷': 50,
#  '感到': 50,
#  '婦女': 50,
#  '孩童': 50,
#  '家園': 50,
#  '來自': 50,
#  '儘管': 50,
#  '指揮官': 50,
#  '13': 50,
#  '合作': 50,
#  '20': 50,
#  '抗議': 50,
#  '空中': 50,
#  '避難': 50,
#  '一直': 49,
#  '西法': 49,
#  '醫生': 49,
#  '停止': 49,
#  '敘利亞': 49,
#  '期間': 49,
#  '機場': 49,
#  '戰略': 49,
#  '食物': 49,
#  '尼斯': 49,
#  '專家': 49,
#  '習近平': 48,
#  '根本': 48,
#  '面對': 48,
#  '一段': 48,
#  '獲得': 48,
#  '其實': 48,
#  '50': 48,
#  '應該': 48,
#  '俘虜': 48,
#  '唯一': 48,
#  '談判': 48,
#  '事實': 48,
#  '川普': 48,
#  '計畫': 48,
#  '越來越': 48,
#  '並且': 48,
#  '討論': 47,
#  '救護車': 47,
#  '部門': 47,
#  '西岸': 47,
#  '兒童': 47,
#  '立即': 47,
#  '人口': 47,
#  '選情': 47,
#  '主播': 47,
#  '如此': 47,
#  '生活': 47,
#  '中心': 46,
#  '暴力': 46,
#  '衛生': 46,
#  '情勢': 46,
#  '最大': 46,
#  '進一步': 46,
#  '這項': 46,
#  '陷入': 46,
#  '立委': 45,
#  '分析': 45,
#  '同意': 45,
#  '不能': 45,
#  '階段': 45,
#  '發出': 45,
#  '即時': 45,
#  '派出': 45,
#  '炸彈': 45,
#  '一樣': 45,
#  '兩國': 45,
#  '恐怖份子': 45,
#  '大家': 45,
#  '同樣': 45,
#  '包含': 45,
#  '進攻': 45,
#  '訊息': 45,
#  '作為': 45,
#  '開槍': 45,
#  '未來': 44,
#  '決定': 44,
#  '隨著': 44,
#  '對抗': 44,
#  '邊界': 44,
#  '升級': 44,
#  '激烈': 44,
#  '據點': 44,
#  '擄走': 44,
#  '立刻': 44,
#  '馬上': 44,
#  '提到': 44,
#  '前線': 44,
#  '萬人': 44,
#  '真的': 43,
#  '母親': 43,
#  '對此': 43,
#  '保持': 43,
#  '社群': 43,
#  '帶回': 43,
#  '時候': 43,
#  '法國': 43,
#  '難民營': 43,
#  '身亡': 43,
#  '設施': 42,
#  '示威': 42,
#  '電視台': 42,
#  '北韓': 42,
#  '不僅': 42,
#  '關卡': 42,
#  '舉行': 42,
#  '正式': 42,
#  '多名': 42,
#  '訓練': 41,
#  '還在': 41,
#  '再次': 41,
#  '確保': 41,
#  '交火': 41,
#  '發表': 41,
#  '南韓': 41,
#  '一起': 41,
#  '葉門': 41,
#  '部署': 41,
#  '會談': 41,
#  '擁有': 40,
#  '外媒': 40,
#  '瞬間': 40,
#  '約旦河': 40,
#  '距離': 40,
#  '突然': 40,
#  '難以': 40,
#  '來到': 40,
#  '15': 40,
#  '即將': 40,
#  '所有人': 40,
#  '開放': 40,
#  '任務': 39,
#  '德國': 39,
#  '相關': 39,
#  '槍手': 39,
#  '事情': 39,
#  '聲稱': 39,
#  '一些': 39,
#  '強烈': 39,
#  '數千': 39,
#  '首都': 39,
#  '各地': 39,
#  '利用': 39,
#  '規模': 39,
#  '不幸': 39,
#  '歐盟': 39,
#  '升溫': 39,
#  '青年': 38,
#  '攔截': 38,
#  '你們': 38,
#  '回家': 38,
#  '表達': 38,
#  '傷患': 38,
#  '國防部': 38,
#  '變成': 38,
#  '女性': 38,
#  '敵人': 38,
#  '努力': 38,
#  '指控': 38,
#  '方面': 38,
#  '方式': 38,
#  '對哈': 38,
#  '不同': 38,
#  '確認': 38,
#  '參加': 38,
#  '參與': 37,
#  '以哈': 37,
#  '領土': 37,
#  '會議': 37,
#  '支援': 37,
#  '隨即': 37,
#  '增加': 37,
#  '曝光': 37,
#  '公司': 37,
#  '學生': 37,
#  '囚犯': 37,
#  '之前': 36,
#  '晚間': 36,
#  '走廊': 36,
#  '所以': 36,
#  '加入': 36,
#  '阻止': 36,
#  '然後': 36,
#  '歐洲': 36,
#  '俄烏': 36,
#  '沒想到': 36,
#  '機構': 36,
#  '接著': 36,
#  '結果': 35,
#  '國旗': 35,
#  '200': 35,
#  '說法': 35,
#  '原因': 35,
#  '猶太': 35,
#  '面臨': 35,
#  '圍困': 35,
#  '防空': 35,
#  '到底': 35,
#  '海軍': 35,
#  '屍體': 35,
#  '有些': 35,
#  '加里': 35,
#  '狀態': 35,
#  '朋友': 35,
#  '鐵穹': 34,
#  '機會': 34,
#  '數十': 34,
#  '宣稱': 34,
#  '恢復': 34,
#  '王毅': 34,
#  '自治': 34,
#  '直到': 34,
#  '擊斃': 34,
#  '趕緊': 34,
#  '平台': 34,
#  '這種': 34,
#  '關鍵': 34,
#  '砲火': 34,
#  '公里': 34,
#  '數百': 34,
#  '或是': 34,
#  '則是': 34,
#  '選擇': 33,
#  '交戰': 33,
#  '拒絕': 33,
#  '抵抗': 33,
#  '歷史': 33,
#  '處理': 33,
#  '聲音': 33,
#  '運送': 33,
#  '遭受': 33,
#  '害怕': 33,
#  '協調': 33,
#  '挾持': 33,
#  '猛烈': 33,
#  '一天': 33,
#  '多個': 33,
#  '力挺': 33,
#  '防空洞': 33,
#  '穆斯林': 33,
#  '猶太人': 33,
#  '立場': 33,
#  '城鎮': 33,
#  '去年': 33,
#  '每天': 32,
#  '16': 32,
#  '這名': 32,
#  '能力': 32,
#  '震驚': 32,
#  '戰機': 32,
#  '聯繫': 32,
#  '經過': 32,
#  '17': 32,
#  '日本': 32,
#  '情緒': 32,
#  '通話': 32,
#  '之下': 32,
#  '特別': 32,
#  '射擊': 32,
#  '經典': 32,
#  '巨大': 32,
#  '招手': 32,
#  '給你': 32,
#  '更加': 32,
#  '新手機': 32,
#  '這段': 32,
#  '千人': 32,
#  '生命': 32,
#  '兩人': 32,
#  '辛瓦': 32,
#  '找到': 32,
#  '建立': 32,
#  '建國': 32,
#  '負責': 31,
#  '此外': 31,
#  '建築物': 31,
#  '加強': 31,
#  '方案': 31,
#  '但是': 31,
#  'vs': 31,
#  '回到': 31,
#  '阿巴斯': 31,
#  '加上': 31,
#  '宣戰': 31,
#  '集團': 31,
#  '社會': 31,
#  '全力': 31,
#  '外國': 31,
#  '鏡頭': 31,
#  '學校': 31,
#  '意外': 31,
#  '街頭': 31,
#  'BenjaminNetanyahu': 31,
#  '葛朗': 31,
#  '重大': 31,
#  '清楚': 31,
#  '交換': 30,
#  '蘇利文': 30,
#  '大屠殺': 30,
#  '背後': 30,
#  '反對': 30,
#  '患者': 30,
#  '親人': 30,
#  '地中海': 30,
#  '電話': 30,
#  '這麼': 30,
#  '採訪': 30,
#  '發展': 30,
#  '土耳其': 30,
#  '電視': 30,
#  '內容': 30,
#  '聚集': 29,
#  '展現': 29,
#  '今年': 29,
#  '航空母艦': 29,
#  '取得': 29,
#  '戰士': 29,
#  '一片': 29,
#  '包圍': 29,
#  '奧斯汀': 29,
#  '得到': 29,
#  '傷害': 29,
#  '手段': 29,
#  '後備': 29,
#  '砲彈': 29,
#  '美元': 29,
#  '尋找': 29,
#  '共同': 28,
#  '存在': 28,
#  '這也': 28,
#  '就連': 28,
#  '19': 28,
#  '自由': 28,
#  '擔憂': 28,
#  '人們': 28,
#  '空軍': 28,
#  '釋出': 28,
#  '準備好': 28,
#  '妻子': 28,
#  '18': 28,
#  '拍下': 28,
#  '深入': 28,
#  '遭遇': 28,
#  '責任': 28,
#  '斡旋': 28,
#  '然而': 28,
#  '明確': 28,
#  '兩個': 28,
#  '爸爸': 28,
#  '天空': 28,
#  '盟友': 28,
#  '斷電': 28,
#  '突破': 28,
#  '仍然': 28,
#  '實現': 28,
#  '隨後': 28,
#  '多次': 28,
#  '響起': 28,
#  '處於': 28,
#  '無論': 28,
#  '公尺': 28,
#  '溝通': 28,
#  '預計': 27,
#  '一間': 27,
#  '旅行社': 27,
#  '想像': 27,
#  '地下': 27,
#  '會面': 27,
#  '提出': 27,
#  '換取': 27,
#  '幫助': 27,
#  '糧食': 27,
#  '戰車': 27,
#  '一旦': 27,
#  '破壞': 27,
#  '火光': 27,
#  '出動': 27,
#  '手機': 27,
#  '暫停': 27,
#  '日前': 27,
#  '砲擊': 27,
#  '哪裡': 27,
#  '半島': 27,
#  '過程': 27,
#  '冒出': 27,
#  '製造': 27,
#  '顧問': 27,
#  '否認': 27,
#  '經歷': 27,
#  '全部': 27,
#  '指揮': 27,
#  '通訊': 27,
#  '態度': 26,
#  '死者': 26,
#  '集結': 26,
#  '逃離': 26,
#  '爆炸聲': 26,
#  '之際': 26,
#  '卡車': 26,
#  '暫時': 26,
#  '迅速': 26,
#  '空投': 26,
#  '民主': 26,
#  '實施': 26,
#  '重新': 26,
#  '聯合': 26,
#  '大學': 26,
#  '台海': 26,
#  '預備': 26,
#  '佔領': 26,
#  '行程': 26,
#  '廢墟': 26,
#  '女孩': 26,
#  '25': 26,
#  '危險': 26,
#  '長期': 26,
#  '清真寺': 26,
#  '家庭': 25,
#  '伊拉克': 25,
#  '21': 25,
#  '沙烏地阿拉伯': 25,
#  '經濟': 25,
#  '車輛': 25,
#  '事務': 25,
#  '地上': 25,
#  '最終': 25,
#  '鎖定': 25,
#  '將在': 25,
#  '一路': 25,
#  '取消': 25,
#  '資訊': 25,
#  '罹難': 25,
#  '先前': 25,
#  '疑似': 25,
#  '資源': 25,
#  '自從': 25,
#  '醫護': 25,
#  '大批': 25,
#  '官方': 25,
#  '闖入': 25,
#  '高度': 25,
#  '稍早': 25,
#  '拍攝': 25,
#  '房屋': 25,
#  '父母': 25,
#  '那裡': 24,
#  '當然': 24,
#  '積極': 24,
#  '領導': 24,
#  '旅遊': 24,
#  '在內': 24,
#  '外交部長': 24,
#  '大使': 24,
#  '22': 24,
#  '人權': 24,
#  '批評': 24,
#  '數字': 24,
#  'Hamas7': 24,
#  '調查': 24,
#  '海上': 24,
#  '選舉': 24,
#  '百姓': 24,
#  '福特': 24,
#  '美聯社': 24,
#  '華府': 24,
#  '救出': 24,
#  '瑪雅': 24,
#  '房子': 24,
#  '阿克薩': 24,
#  '失蹤': 24,
#  '願意': 24,
#  '周圍': 24,
#  '到處': 24,
#  '確定': 24,
#  '接下來': 24,
#  '中部': 24,
#  '這起': 24,
#  '受害': 24,
#  '女子': 24,
#  '帶走': 24,
#  '電力': 24,
#  '美方': 24,
#  '說明': 24,
#  '14': 24,
#  '每個': 24,
#  '高級': 24,
#  '解決': 24,
#  '執行': 24,
#  '500': 23,
#  '40': 23,
#  '統計': 23,
#  '打擊群': 23,
#  '這不': 23,
#  '不明': 23,
#  '議題': 23,
#  '靠近': 23,
#  '地底': 23,
#  '演說': 23,
#  '獨立': 23,
#  '槍聲': 23,
#  '明顯': 23,
#  '引爆': 23,
#  '幾個': 23,
#  '媽媽': 23,
#  '納克': 23,
#  '男孩': 23,
#  '炸毀': 23,
#  '災難': 23,
#  '悲劇': 23,
#  '在一起': 23,
#  '升高': 23,
#  '而是': 23,
#  '被迫': 23,
#  '不到': 23,
#  '下令': 23,
#  '聲響': 23,
#  '才能': 23,
#  '尋求': 23,
#  '避難所': 23,
#  '占領': 23,
#  '解放': 23,
#  '出來': 23,
#  '黑煙': 23,
#  '活著': 23,
#  '帶著': 23,
#  '流離失所': 23,
#  '發文': 23,
#  '政策': 23,
#  '卡薩': 23,
#  '央視': 23,
#  '遭哈': 23,
#  '基礎': 23,
#  '為什麼': 23,
#  '土地': 23,
#  '大使館': 23,
#  '力量': 23,
#  '平安': 23,
#  '基本': 23,
#  '紅海': 22,
#  '大約': 22,
#  '萬名': 22,
#  '聯盟': 22,
#  '對話': 22,
#  '泰國': 22,
#  '躲進': 22,
#  '反應': 22,
#  '留下': 22,
#  '凌晨': 22,
#  '紐約': 22,
#  '順利': 22,
#  '兄弟': 22,
#  '辦公室': 22,
#  '倖存': 22,
#  '當天': 22,
#  '內部': 22,
#  '目擊': 22,
#  '新聞網': 22,
#  '代價': 22,
#  '相信': 22,
#  '飛機': 22,
#  '穩定': 22,
#  '會晤': 22,
#  '峰會': 22,
#  '發起': 22,
#  '彈藥': 22,
#  '治療': 22,
#  '瞄準': 22,
#  '幾天': 22,
#  '目的': 22,
#  '一家': 22,
#  '通過': 22,
#  '目睹': 22,
#  '價格': 22,
#  '也將': 22,
#  '分鐘': 22,
#  '東西': 22,
#  '覺得': 22,
#  '侵略': 22,
#  '容易': 22,
#  '甘尤': 22,
#  '聲援': 22,
#  '細節': 22,
#  '地帶': 22,
#  '記者會': 22,
#  '延長': 22,
#  '達到': 22,
#  '感謝': 21,
#  '上午': 21,
#  '航母': 21,
#  '一條': 21,
#  '有關': 21,
#  '位在': 21,
#  '全世界': 21,
#  '黃金': 21,
#  '堅定': 21,
#  '長達': 21,
#  '終於': 21,
#  '移動': 21,
#  '國人': 21,
#  '卡桑': 21,
#  '解救': 21,
#  '監獄': 21,
#  '不滿': 21,
#  '單位': 21,
#  '了解': 21,
#  '100': 21,
#  '統治': 21,
#  '收到': 21,
#  '表明': 21,
#  '外國人': 21,
#  '竟然': 21,
#  '還說': 21,
#  '一定': 21,
#  '各種': 21,
#  '服務': 21,
#  '最近': 21,
#  ...}

# %%
# 繪製文字雲
wordcloud = WordCloud(background_color = 'white', width = 800, height = 400, font_path = FontPath, max_words = 50)
wordcloud.generate_from_frequencies(freq_dict)

plt.figure(figsize = (10,7))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 4.7 移除停用字

# %%
# 以檔案形式匯入通用的停用字檔案
# 將stopwords存成list
stopwords = [line.strip() for line in open('dict/stopwords.txt', 'r', encoding='utf-8').readlines()]

# %% [markdown]
# 移除dataframe中的停用字

# %%
noStop_df = word_df[~word_df['word'].isin(stopwords)]
noStop_df.head(10)
# Out:
#                               artTitle          artDate  \
# 0  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 0  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 0  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
#
#                                           artContent  word
# 0  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...   法新社
# 0  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    記者
# 0  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    報導
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...   以色列
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    軍隊
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    今天
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...  加薩走廊
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    發動
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    至少
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    空襲

# %% [markdown]
# ### 計算去除停用字後的詞頻

# %% [markdown]
# #### 再次繪製長條圖

# %%
freq_df_nostop = pd.DataFrame(pd.value_counts(noStop_df['word'])).sort_values(by = ['count'], ascending = False).reset_index()

freq_df_nostop.head(10).plot.barh(x = 'word', y = 'count').invert_yaxis()
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7716\583685406.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   freq_df_nostop = pd.DataFrame(pd.value_counts(noStop_df['word'])).sort_values(by = ['count'], ascending = False).reset_index()

# %% [markdown]
# #### 再次繪製文字雲

# %%
freq_dict_nostop = freq_df_nostop.set_index('word').to_dict()
freq_dict_nostop = freq_dict_nostop['count']

# 繪製文字雲
wordcloud_nostop = WordCloud(background_color = 'white', width = 800, height = 400, font_path = FontPath, max_words = 50)
wordcloud_nostop.generate_from_frequencies(freq_dict_nostop)

plt.figure(figsize = (10,7))
plt.imshow(wordcloud_nostop)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 4.8 更新停用字字典

# %%
# 參數形式手動加入停用字
stopwords_manual = ["以色列", "巴勒斯坦", "以巴衝突", "現在", "目前", "地址", "營業", "看到", "指出", "10"]
stopwords.extend(stopwords_manual)

# %%
noStop_df_2 = noStop_df[~noStop_df['word'].isin(stopwords)]
noStop_df_2.head(10)
# Out:
#                               artTitle          artDate  \
# 0  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 0  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 0  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 3  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
#
#                                           artContent  word
# 0  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...   法新社
# 0  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    記者
# 0  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    報導
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    軍隊
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    今天
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...  加薩走廊
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    發動
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    至少
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    空襲
# 3  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    瑪斯

# %% [markdown]
# ### 4.9 更新斷詞字典
# 更新斷詞字典有兩種方法

# %% [markdown]
# a. 自行定義的斷詞字典

# %%
# 載入自定義辭典：一個詞一行，每行分詞語、詞頻(可省)、詞性(可省)
jieba.load_userdict("dict/user_dict.txt")

# %% [markdown]
# #### 重新斷詞

# %%
# sent_df是還沒斷詞過的df
word_df_updated = sent_df.assign(word = sent_df['sentence'].apply(jieba.lcut)).explode('word').drop(['sentence'], axis=1)

#把長度小於1的row刪掉
word_df_updated = word_df_updated.loc[word_df_updated['word'].str.len()>1]
word_df_updated
# Out:
#                                   artTitle          artDate  \
# 0      以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 0      以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 0      以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1      以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1      以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# ...                                    ...              ...
# 24352            以巴衝突滿五個月！ 美軍持續空投加薩物資｜東森新聞   3/6/2024 17:16
# 24352            以巴衝突滿五個月！ 美軍持續空投加薩物資｜東森新聞   3/6/2024 17:16
# 24352            以巴衝突滿五個月！ 美軍持續空投加薩物資｜東森新聞   3/6/2024 17:16
# 24352            以巴衝突滿五個月！ 美軍持續空投加薩物資｜東森新聞   3/6/2024 17:16
# 24352            以巴衝突滿五個月！ 美軍持續空投加薩物資｜東森新聞   3/6/2024 17:16
#
#                                               artContent word
# 0      法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...  法新社
# 0      法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...   記者
# 0      法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...   報導
# 1      法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...  以色列
# 1      法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...   軍隊
# ...                                                  ...  ...
# 24352  堆高機把物資放到運輸機上，箱子旁印著約旦國旗，還有手寫字條，寫著與你同在為你祈禱。約旦空軍5...   更多
# 24352  堆高機把物資放到運輸機上，箱子旁印著約旦國旗，還有手寫字條，寫著與你同在為你祈禱。約旦空軍5...   救援
# 24352  堆高機把物資放到運輸機上，箱子旁印著約旦國旗，還有手寫字條，寫著與你同在為你祈禱。約旦空軍5...   物資
# 24352  堆高機把物資放到運輸機上，箱子旁印著約旦國旗，還有手寫字條，寫著與你同在為你祈禱。約旦空軍5...   進到
# 24352  堆高機把物資放到運輸機上，箱子旁印著約旦國旗，還有手寫字條，寫著與你同在為你祈禱。約旦空軍5...   加薩
#
# [114771 rows x 4 columns]

# %% [markdown]
# #### 重新移除停用字

# %%
nostop_df_updated = word_df_updated[~word_df_updated['word'].isin(stopwords)]

nostop_df_updated
# Out:
#                                   artTitle          artDate  \
# 0      以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 0      以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 0      以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1      以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1      以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# ...                                    ...              ...
# 24352            以巴衝突滿五個月！ 美軍持續空投加薩物資｜東森新聞   3/6/2024 17:16
# 24352            以巴衝突滿五個月！ 美軍持續空投加薩物資｜東森新聞   3/6/2024 17:16
# 24352            以巴衝突滿五個月！ 美軍持續空投加薩物資｜東森新聞   3/6/2024 17:16
# 24352            以巴衝突滿五個月！ 美軍持續空投加薩物資｜東森新聞   3/6/2024 17:16
# 24352            以巴衝突滿五個月！ 美軍持續空投加薩物資｜東森新聞   3/6/2024 17:16
#
#                                               artContent word
# 0      法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...  法新社
# 0      法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...   記者
# 0      法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...   報導
# 1      法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...   軍隊
# 1      法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...   今天
# ...                                                  ...  ...
# 24352  堆高機把物資放到運輸機上，箱子旁印著約旦國旗，還有手寫字條，寫著與你同在為你祈禱。約旦空軍5...   更多
# 24352  堆高機把物資放到運輸機上，箱子旁印著約旦國旗，還有手寫字條，寫著與你同在為你祈禱。約旦空軍5...   救援
# 24352  堆高機把物資放到運輸機上，箱子旁印著約旦國旗，還有手寫字條，寫著與你同在為你祈禱。約旦空軍5...   物資
# 24352  堆高機把物資放到運輸機上，箱子旁印著約旦國旗，還有手寫字條，寫著與你同在為你祈禱。約旦空軍5...   進到
# 24352  堆高機把物資放到運輸機上，箱子旁印著約旦國旗，還有手寫字條，寫著與你同在為你祈禱。約旦空軍5...   加薩
#
# [95958 rows x 4 columns]

# %% [markdown]
# 重新進行斷詞及清除停用字

# %%
# sent_df是還沒斷詞過的df
word_df_updated = sent_df.assign(word = sent_df['sentence'].apply(jieba.lcut)).explode('word').drop(['sentence'], axis=1)

#把長度小於1的row刪掉
word_df_updated = word_df_updated.loc[word_df_updated['word'].str.len()>1]

#去除停用字
nostop_df_updated = word_df_updated[~word_df_updated['word'].isin(stopwords)]

nostop_df_updated.head(10)
# Out:
#                               artTitle          artDate  \
# 0  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 0  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 0  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 1  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
# 3  以色列空襲回擊哈瑪斯！總理宣布戰爭狀態 喊話：敵人將付出代價｜東森新聞  10/7/2023 18:49
#
#                                           artContent  word
# 0  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...   法新社
# 0  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    記者
# 0  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    報導
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    軍隊
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    今天
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...  加薩走廊
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    發動
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    至少
# 1  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    空襲
# 3  法新社記者報導，以色列軍隊今天已對加薩走廊發動至少2次空襲。在此之前，哈瑪斯集團從加薩走廊向...    瑪斯

# %% [markdown]
# 經過比對可以看到該詞的數量上升，代表該詞更加精準地被拆分了出來。

# %% [markdown]
# #### 重新計算詞頻

# %%
freq_df_updated = pd.DataFrame(pd.value_counts(nostop_df_updated['word'])).sort_values(by = ['count'], ascending = False).reset_index()

freq_df_updated
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7716\4165249668.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   freq_df_updated = pd.DataFrame(pd.value_counts(nostop_df_updated['word'])).sort_values(by = ['count'], ascending = False).reset_index()
#       word  count
# 0       瑪斯   2038
# 1       加薩   1429
# 2       美國    851
# 3       攻擊    642
# 4       表示    632
# ...    ...    ...
# 13606   車內      1
# 13607   哀嚎      1
# 13608  求救聲      1
# 13609   還以      1
# 13610   應證      1
#
# [13611 rows x 2 columns]

# %% [markdown]
# #### 重新繪製詞頻長條圖

# %%
freq_df_updated.head(10).plot.barh(x='word', y='count').invert_yaxis()
plt.show()

# %% [markdown]
# #### 繪製文字雲

# %%
freq_dict_updated = freq_df_updated.set_index('word').to_dict()
freq_dict_updated = freq_dict_updated['count']

# 繪製文字雲
wordcloud_after = WordCloud(background_color='white', width=800, height = 400, font_path = FontPath, max_words = 50)
wordcloud_after.generate_from_frequencies(freq_dict_updated)

plt.figure(figsize = (10,7))
plt.imshow(wordcloud_after)
plt.axis('off')
plt.show()

# %% [markdown]
# ### 4.10 比較清理前後的文字雲

# %%
plt.figure(figsize = (14,8))

plt.subplot(1,2,1)
plt.imshow(wordcloud)
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(wordcloud_after)
plt.axis('off')

plt.show()

# %% [markdown]
# 儲存clean data，以便後續其他使用

# %%
nostop_df_updated.to_csv("raw_data/clean_zh_data.csv", encoding = 'utf-8',index = False)

# %% [markdown]
# 資料清理的過程往往是花費做多時間的工程，因為在做完第一次的斷詞、正規化、清除停用字後，我們會發現還是會有許多不重要的字沒有被清理到，或是有些兩個字以上的專有名詞、名詞片語被斷開，因此在進行資料分析前，必須不斷經歷以上過程，更新停用字、字典，以便在後續的分析中能得到重要且正確的分析結果
